# %%
import pandas as pd
df = pd.read_json('orders.json', orient='columns')
print(df)
# Out:
#                                     completed_orders  \
# 0  {'session_id': 'session_1776368021500_5kbo497o...
# 1  {'session_id': 'session_1776368021500_5kbo497o...
# 2  {'session_id': 'session_1776520024206_be5bmamn...
#
#                  last_updated
# 0  2026-04-18T18:48:18.628859
# 1  2026-04-18T18:48:18.628859
# 2  2026-04-18T18:48:18.628859
